# %% [markdown]
# # EDA With Red Wine Data
#
# Data set information:
#
# The two datasets are related to red and white variants of the Portuguese " Vinho Verde" wine. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available ( e.g. there is no data about grape types, with brand, wine selling price, etc)
#
# These datasets can be viewed as classification or regresssion tasks. The classes are ordered and not balanced ( e.g. there are many more normal wines than excellent or poor ones).
#
# Outlier detection algorithms could be used to detect the few excellent or poor wines. Also , we are not sure if all input variables are relevant . So it could be interesting to test feature selection methods.
#
#
# Attribute information:
#
# input variables (based on Physicochemical tests):
#
# + 1- fixed acidity
# + 2- volatile acidity
# + 3- citric acid
# + 4- residual sugar
# + 5- chlorides
# + 6- fress sulfure dioxide
# + 7- total sulfur dioxide
# + 8- density
# + 9- pH
# + 10- sulphates
# + 11- alcohol
#
# Output variable (based on sensory data):
#
# + 12- quality (score between 0 and 10)

# %%
import pandas as pd 
df = pd.read_csv('winequality-red.csv', sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Summary of the dataset 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# all are in float value and only quality is in int value .
#
# now we have to clean it and trandform it . lets do it .

# %%
# descriptive summary of the dataset 

df.describe ()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.shape #It is an ATTRIBUTE (property) of the DataFrame. (rows, columns)
# Out:
# (1599, 12)

# %%
# List down al the columns names 

df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['quality'].unique() 

# it tell the unique values in the column.
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# Missing values in the dataset 

df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
#  So there is  no null value .
#
# Now lets see if there is any duplicate in this dataset.

# %%
df.duplicated()  # it tell in true or false .
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
## Duplicate records

df[df.duplicated()]  # now this is in table .
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
# Remove the duplicate 

df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (1359, 12)

# %%
# # correlation 

df.corr()  

# it calculates correlation between numeric columns only.

# +1 --> Perfect positive relation
# -1 --> Perfect negative relation

# 0 --> No relation.
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df = pd.read_csv("winequality-red.csv", sep=";")
df.shape
df.corr().head()
# Out:
#                   fixed acidity  volatile acidity  citric acid  \
# fixed acidity          1.000000         -0.256131     0.671703
# volatile acidity      -0.256131          1.000000    -0.552496
# citric acid            0.671703         -0.552496     1.000000
# residual sugar         0.114777          0.001918     0.143577
# chlorides              0.093705          0.061298     0.203823
#
#                   residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity           0.114777   0.093705            -0.153794
# volatile acidity        0.001918   0.061298            -0.010504
# citric acid             0.143577   0.203823            -0.060978
# residual sugar          1.000000   0.055610             0.187049
# chlorides               0.055610   1.000000             0.005562
#
#                   total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                -0.113181  0.668047 -0.682978   0.183006
# ...

# %%
# Now lets seee the graphs 

import matplotlib.pyplot as plt 

import seaborn as sns

plt.figure(figsize=(10,6))  # it is important to adjust to look good .

sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Visualization
# Conclusion - it is an imbalanced dataset

df.quality.value_counts().plot(kind='bar')
plt.xlabel("wine Quality")
plt.ylabel("Count")
plt.show()

# value_counts() = How many times each unique value appears in a column.

# %% [markdown]
# 🧠 WHAT IT IS USED FOR (REAL ANALYST USE)
#
# You use value_counts() to:
# ✅ Check class imbalance
#
# ✅ Check categorical distribution
#
# ✅ Detect data bias
#
# ✅ Decide if SMOTE / sampling is needed
#
# ✅ Spot dirty values

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
for column in df.columns:
    sns.histplot(df[column],kde=True)

# What is kde=True?

# kde = Kernel Density Estimation : It is used in plts( mostly with histograms) to shw a smooth probability density curve over the data.

# %% [markdown]
# ✅ When to use kde=True
#
# Use it when you want to:
#
# Understand data distribution
#
# Check if data is:
#
# 1. Normal
#
# 2. Skewed
#
# 3. Multi-modal

# %%
df['alcohol'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
# univariate , bivariate, multivariate analysis

sns.pairplot(df)

# %%
# categorical plot 

sns.catplot(x='quality' , y='alcohol' , data = df, kind = "box")

# %% [markdown]
# This shows the outliers , as u can see 3 and 5 has outlier .

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
sns.scatterplot(x='alcohol' , y='pH' ,hue='quality', data = df)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>

# %%
import matplotlib.pyplot as plt

for column in df.select_dtypes(include='number').columns:  # it returns a DataFrame containing only numeric columns .
    plt.figure()
    sns.histplot(df[column], kde=True)
    plt.title(column)
    plt.show()

# %% [markdown]
# ✅ Only numeric columns
#
# ✅ One plot per column
#
# ✅ Proper visualization
#
# ✅ Interview-safe code
#
# 🧠 WHAT A REAL ANALYST SAYS
#
# “I visualize only numeric features using histograms and KDE to understand skewness and distribution.”
#
# You? You were just spamming plots without filtering. That’s not EDA — that’s panic coding.
